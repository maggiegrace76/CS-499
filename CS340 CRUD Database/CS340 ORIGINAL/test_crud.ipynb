# %%
# Test CRUD operations using the AnimalShelter class
from crud_module import AnimalShelter

# Connect using aacuser account (replace with correct password if needed)
shelter = AnimalShelter('aacuser', 'password')

# Test Create
new_dog = {'name': 'Buddy', 'breed': 'Labrador', 'age_upon_outcome': '1 year'}
print('Create:', shelter.create(new_dog))

# Test Read
print('Read:', shelter.read({'name': 'Buddy'}))

# Test Update
print('Update:', shelter.update({'name': 'Buddy'}, {'breed': 'Golden Retriever'}))

# Test Delete
print('Delete:', shelter.delete({'name': 'Buddy'}))
